# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd 
from collections import Counter
import os
import glob
import copy
import seaborn as sns
import matplotlib.pyplot as plt
import umap
import scipy.stats as stats
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
import math

# %% [markdown]
# ### Read every cohort study file

# %%
datasets = [pd.read_csv(file, index_col=0, low_memory=False) for file in sorted(glob.glob('../cohort_studies_full_data/' + "/*."+'csv'))]
cohorts = [file.split(".")[0] for file in sorted(os.listdir('../cohort_studies_full_data/'))]

# %%
# make a dictionary that contains all cohorts as a dataframe
cohort_studies = dict()
# dfsss = dict()

for cohort, dataset in zip(cohorts, datasets):
    cohort_n = cohort.split("_MERGE")[0]
    cohort_studies[cohort_n] = dataset.loc[dataset['Months']==0].copy() # reduce to BL visit
#     dfsss[cohort_n] = dataset

# %%
datasets_sub = [pd.read_csv(file, index_col=0, low_memory=False) for file in sorted(glob.glob('../preprocessed_datasets/' + "/*."+'csv'))]
cohorts_sub = [file.split(".")[0] for file in sorted(os.listdir('../preprocessed_datasets/'))]

# %%
# make a dictionary that contains all cohorts as a dataframe
cohort_studies_sub = dict()

for cohort, dataset in zip(cohorts_sub, datasets_sub):
    cohort_studies_sub[cohort] = dataset.loc[dataset['Months']==0].copy() # reduce to BL visit

# %%
# add the preprocessed columns from sub table of each dataset to the main table of dataset
for i in cohort_studies:
#     cols = cohort_studies_sub[i].columns.difference(cohort_studies[i].columns)
    cols = ['Age', 'Sex', 'Education', 'APOE4', 'CDR', 'Race']
    
    for col in cols:
        
        if col in cohort_studies_sub[i].columns:
            cohort_studies[i][col] = cohort_studies_sub[i][col]

# %% [markdown]
# ### Read harmonized mapping tables

# %%
modality = [pd.read_csv(file, sep=',') for file in sorted(glob.glob('../feature_tables' + "/*."+'csv'))]
name = [file.split(".")[0] for file in sorted(os.listdir('../feature_tables'))]

# %%
# make a dictionary that contains all modalities as a dataframe
mappings = dict()

for moda, na in zip(modality, name):
    mappings[na.split(' - ')[1]] = moda

# %%
harmonized_features = pd.concat(mappings, ignore_index=True) # combine all tables

# %%
# exclude categorical and taboo features
harmonized_features = harmonized_features.loc[(harmonized_features['Rank']!=1) & (harmonized_features['Rank']!=2)]

# %% [markdown]
# ### Read the feature availability files for all cohorts

# %%
ava_mapp = [pd.read_csv(file, sep='\t') for file in sorted(glob.glob('../feature_availability_in_cohorts' + "/*."+'tsv'))]
tablesss = [file.split(".")[0] for file in sorted(os.listdir('../feature_availability_in_cohorts'))]

# %%
# make a dictionary that contains all modalities as a dataframe
available_features = dict()

for modal, df in zip(tablesss, ava_mapp):
    available_features[modal] = df

# %%
existing_features = pd.concat(available_features, ignore_index=True) # combine all tables

# %%
existing_features.replace({0: np.nan}, inplace=True) # 0 indicates that the feature was not measured

# %%
test = existing_features.set_index('Feature')

# %%
test = test[test.loc['pTau in CSF'].dropna().index]

# %%
for i in test.columns:
    print(i, Counter(test[test.loc['pTau in CSF'].dropna().index][i].dropna()))
# Out:
# ADNI Counter({1.0: 333})
# AIBL Counter({1.0: 58})
# ARWIBO Counter({1.0: 1078})
# DOD-ADNI Counter({1.0: 320})
# EDSD Counter({1.0: 1026})
# EMIF Counter({1.0: 30})
# EPAD Counter({1.0: 134})
# JADNI Counter({1.0: 936})
# NACC Counter({1.0: 187})
# PREVENT-AD Counter({1.0: 36})
# PharmaCog Counter({1.0: 1057})

# %%
features_selected_ = test[test.columns.difference(['AIBL', 'JADNI', 'EMIF', 'DOD-ADNI', 'PREVENT-AD', 'NACC'])].dropna(thresh=5, axis=0).index.to_list()

# %% [markdown]
# ### Read cutoffs obtained using all methods

# %%
table_method = [pd.read_csv(file, index_col=0, low_memory=False) for file in sorted(glob.glob('../results/cutoffs/' + "/*."+'csv'))]
method_name = [file.split(".")[0] for file in sorted(os.listdir('../results/cutoffs/'))]

# %%
# make a dictionary that contains each cutoff table as a dataframe
cutoffs_ = dict()

for tm, mn in zip(table_method, method_name):
    cutoffs_[mn] = tm

# %%
[cutoffs_['km_cutoffs'].rename(columns={col: col.split('_')[0]}, inplace=True) for col in cutoffs_['km_cutoffs'].columns]
# Out:
# [None, None, None]

# %% [markdown]
# ### Selecetion of cohort studies for A/T/N assignment

# %% [markdown]
# ### Select the patient that have CSF biomarker, disregard the diagnostic status

# %%
atn = pd.DataFrame(index=available_features['csf'].iloc[:3].replace({0: np.nan}).dropna(axis=1).columns[1:].to_list(), columns=mappings['csf'].Feature.loc[0:2].to_list()+(["Total"]))
# atn = pd.DataFrame(index=cohort_studies, columns=['A', 'T', 'N'])

# %%
for cohort in atn.index:
    for feat in mappings['csf'][cohort].loc[0:2].dropna().to_list():
        if feat in cohort_studies[cohort].columns:
            atn.loc[cohort, mappings['csf'].loc[mappings['csf'][cohort]==feat, 'Feature']] = len(cohort_studies[cohort][feat].dropna())
            atn.loc[cohort, 'Total'] = len(cohort_studies[cohort][mappings['csf'][cohort].loc[0:2].dropna().to_list()].dropna())

# %%
# atn

# %%
diag = pd.DataFrame(index=available_features['csf'].iloc[:3].replace({0: np.nan}).dropna(axis=1).columns[1:].to_list(), columns=cohort_studies['ADNI']['Diagnosis'].dropna().unique())

# %%
for cohort in diag.index:
    for dia in diag.columns:
        diag.loc[cohort, dia] = len(cohort_studies[cohort].loc[cohort_studies[cohort]['Diagnosis']==dia][mappings['csf'][cohort].loc[0:2].dropna().to_list()].dropna())

# %% [markdown]
# ### Remove the empty columns from all cohorts that we are intrested in
# ### Remove the participant without all 3 CSF biomarkers

# %%
selected_cohorts = dict()

for coh in diag.index:
    selected_cohorts[coh] = cohort_studies[coh].dropna(axis=1, how='all')

# %%
total_feats = dict()

# existing_features.set_index('Feature', inplace=True)

for feat in existing_features.Feature:
    total_feats[feat] = existing_features.loc[existing_features.Feature==feat][selected_cohorts].dropna(axis=1).columns

# %%
for cohort in atn.index:
    feat = mappings['csf'][cohort].loc[0:2].dropna().to_list()
    cohort_studies[cohort] = cohort_studies[cohort].dropna(subset=feat)

# %% [markdown]
# As Some features have suffix due to merging tables for certain cohorts, first investigate if all the harmonized features are in cohorts. Rename the ones that have suffix so it can be compatible to work with our harmonized names.

# %%
cohort_studies['ADNI'] = cohort_studies['ADNI'].rename(columns={'PTEDUCAT_x': 'PTEDUCAT', 'TRABSCOR_bl': 'TRABSCOR', 'LDELTOTAL_BL': 'LDELTOTAL'})

# %% [markdown]
# ### CSF biomarkers, two classes, normal vs abnormal

# %%
# cohorts_csf = dict()

# for i in atn.index:
    
#     csf = mappings['csf'].iloc[:3][i].to_list()
#     cohorts_csf[i] = cohort_studies[i][csf + ["Diagnosis", "Age"]]
#     cohorts_csf[i] = cohorts_csf[i].dropna(subset=cohorts_csf[i].columns[:3].to_list() + ['Age']) # drop empty rows (CSF biomarkers)
       
#     #     for col in ['A', 'T', 'N']:
#     #         cohorts_csf[i][col]=np.nan

# %%
# td = pd.concat(mappings, ignore_index=True)
# td.loc
# td.loc[td['Rank']== 1]['Feature']

# %%
# modality_ = ['clinical_i', 'clinical_ii','hippocampus', 'csf']
modality_ = ['basal_ganglia', 'brain_poles_volume', 'cerebellum', 'clinical_i', 
            'clinical_ii', 'csf', 'diencephalus', 'general_brain', 
            'mri_others', 'pet', 'plasma', 'ventricles', 'hippocampus']

selected_feat = dict()

for i in modality_:
    selected_feat[i] = mappings[i]

# %%
# make a dataframe containing all the mapped features
features_all = pd.concat(selected_feat, ignore_index=True)

# %%
features_all = features_all[atn.index.union(['Feature', 'Rank'])] # subset the cohorts of interest

# %%
# remove the features that are not available in all studies
features_all = features_all.loc[features_all['Feature'].isin(existing_features[atn.index.union(['Feature'])].dropna(how='all')['Feature'].to_list())]

# %% [markdown]
# * Rank 1 --> Categorical features
# * Rank 2 --> Taboo features: some categorical and some numerical
# * Rank nan --> Numerical features
#
# replace nan with 0

# %%
features_all['Rank'].replace({np.nan: 0}, inplace=True)

# %%
features_all.replace({"No total score.": np.nan}, inplace=True)

# %% [markdown]
# ## Prepare datasets

# %%
# f_= pd.DataFrame(columns=set(features_all.loc[features_all['Rank']==0]
#                                   [['DOD-ADNI', 'JADNI'] + ['Feature']].dropna()['Feature']).difference(['Feature'] + list(cutoffs_['gmm_cutoffs'].columns)).union(['Age', 'Sex', 'Education', 'APOE4', 'CDR', 'Race']))

# %%
# features_all[['ADNI', 'DOD-ADNI']].dropna()['DOD-ADNI']

# %%
# print(cohort_studies['ADNI'][features_all[['ADNI', 'DOD-ADNI']].dropna()['ADNI']].isna().sum())

# %%
# cohort_studies['ADNI'][features_all[['ADNI', 'DOD-ADNI']].dropna()['ADNI']].dropna(axis=1, how='all').dropna()

# %%
# cohort_studies['DOD-ADNI'][features_all[['ADNI', 'DOD-ADNI']].dropna()['DOD-ADNI']].dropna(axis=1, how='all').dropna()

# %%
Counter(features_all['JADNI'].dropna())
# Out:
# Counter({'(Left-Putamen)Volume_mm3': 1,
#          '(Left-Pallidum)Volume_mm3': 1,
#          '(Left-Amygdala)Volume_mm3': 1,
#          '(Left-Accumbens-area)Volume_mm3': 1,
#          '(Right-Caudate)Volume_mm3': 1,
#          '(Right-Putamen)Volume_mm3': 1,
#          '(Right-Pallidum)Volume_mm3': 1,
#          '(Right-Amygdala)Volume_mm3': 1,
#          '(Right-Accumbens-area)Volume_mm3': 1,
#          'rh_(temporalpole)GrayVol': 1,
#          'lh_(frontalpole)GrayVol': 1,
#          'lh_(temporalpole)GrayVol': 2,
#          '(Pole_occipital)GrayVol': 2,
#          '(Pole_temporal)GrayVol': 2,
#          '(Right-Cerebellum-Cortex)Volume_mm3': 1,
#          '(Right-Cerebellum-White-Matter)Volume_mm3': 1,
#          'DXCURREN': 1,
#          'CDGLOBAL': 1,
#          'CDR-SOB': 1,
#          'MMSCORE': 1,
#          'GDTOTAL': 1,
#          'TOTAL11': 1,
#          'TOTALMOD': 1,
#          'FAQTOTAL': 1,
#          'NPISCORE': 1,
#          'BNTTOTAL': 1,
#          'CATANIMSC': 1,
#          'CATVEGESC': 1,
#          'CLOCKSCOR': 1,
#          'LDELTOTAL': 1,
#          'AVDELTOT': 1,
#          'HMSCORE': 1,
#          'ANARTERR': 1,
#          'TRAASCOR': 1,
#          'TRABSCOR': 1,
#          'DSPANFOR': 1,
#          'DSPANBAC': 1,
#          'CSF PTAU': 1,
#          'CSF TAU': 1,
#          'CSF AB': 1,
#          '(Left-Thalamus-Proper)Volume_mm3': 1,
#          '(Left-VentralDC)Volume_mm3': 1,
#          '(Right-Thalamus-Proper)Volume_mm3': 1,
#          '(Right-VentralDC)Volume_mm3': 1,
#          'CortexVol': 2,
#          'CorticalWhiteMatterVol': 1,
#          '(WM-hypointensities)Volume_mm3': 2,
#          'rhCortexVol': 2,
#          'lhCorticalWhiteMatterVol': 2,
#          'rhCorticalWhiteMatterVol': 2,
#          'ICV': 1,
#          'lh_(entorhinal)GrayVol': 2,
#          'rh_(entorhinal)GrayVol': 2,
#          'lh_(fusiform)GrayVol': 1,
#          'rh_(fusiform)GrayVol': 2,
#          'lh_(middletemporal)GrayVol': 1,
#          'rh_(middletemporal)GrayVol': 1,
#          '(Left-Cerebellum-Cortex)Volume_mm3': 1,
#          '(Left-Cerebellum-White-Matter)Volume_mm3': 1,
#          '(Left-Caudate)Volume_mm3': 1,
#          'lhCortexVol': 2,
#          'rh_(pericalcarine)GrayVol': 1,
#          'rh_(precentral)GrayVol': 1,
#          'rh_(rostralmiddlefrontal)GrayVol': 1,
#          'rh_(superiorparietal)GrayVol': 1,
#          'rh_(supramarginal)GrayVol': 1,
#          'rh_(insula)GrayVol': 2,
#          'lh_(cuneus)GrayVol': 2,
#          'lh_(inferiortemporal)GrayVol': 2,
#          'lh_(medialorbitofrontal)GrayVol': 1,
#          'lh_(pericalcarine)GrayVol': 1,
#          'lh_(precentral)GrayVol': 1,
#          'lh_(rostralmiddlefrontal)GrayVol': 1,
#          'lh_(supramarginal)GrayVol': 1,
#          'rh_(caudalmiddlefrontal)GrayVol': 2,
#          '(Right-choroid-plexus)Volume_mm3': 1,
#          'rh_(frontalpole)GrayVol': 1,
#          'rh_(inferiortemporal)GrayVol': 2,
#          'rh_(medialorbitofrontal)GrayVol': 1,
#          'lh_(parahippocampal)GrayVol': 1,
#          'rh_(parahippocampal)GrayVol': 1,
#          '(4th-Ventricle)Volume_mm3': 1,
#          'lh_(superiorparietal)GrayVol': 1,
#          'rh_(paracentral)GrayVol': 2,
#          'rh_(postcentral)GrayVol': 1,
#          'rh_(superiorfrontal)GrayVol': 1,
#          'rh_(superiortemporal)GrayVol': 1,
#          'lh_(insula)GrayVol': 2,
#          'lh_(caudalmiddlefrontal)GrayVol': 1,
#          '(Left-choroid-plexus)Volume_mm3': 1,
#          'lh_(inferiorparietal)GrayVol': 2,
#          'lh_(lateraloccipital)GrayVol': 1,
#          'lh_(lingual)GrayVol': 1,
#          'lh_(paracentral)GrayVol': 1,
#          'lh_(postcentral)GrayVol': 1,
#          'lh_(superiorfrontal)GrayVol': 1,
#          'lh_(superiortemporal)GrayVol': 2,
#          'rh_(cuneus)GrayVol': 2,
#          'rh_(inferiorparietal)GrayVol': 2,
#          'rh_(lateraloccipital)GrayVol': 1,
#          'rh_(lingual)GrayVol': 2,
#          'lh_(parsopercularis)GrayVol': 1,
#          'rh_(parsopercularis)GrayVol': 1,
#          'lh_(parsorbitalis)GrayVol': 1,
#          'rh_(parsorbitalis)GrayVol': 1,
#          'rh_(parstriangularis)GrayVol': 1,
#          'lh_(parstriangularis)GrayVol': 1,
#          'lh_(posteriorcingulate)GrayVol': 1,
#          'rh_(posteriorcingulate)GrayVol': 1,
#          'lh_(rostralanteriorcingulate)GrayVol': 1,
#          'rh_(rostralanteriorcingulate)GrayVol': 1,
#          '(Brain-Stem)Volume_mm3': 1,
#          '(CSF)Volume_mm3': 1,
#          '(Left-vessel)Volume_mm3': 1,
#          'lh_(caudalanteriorcingulate)ThickAvg': 1,
#          'rh_(caudalanteriorcingulate)ThickAvg': 1,
#          'lh_(caudalmiddlefrontal)ThickAvg': 1,
#          'rh_(caudalmiddlefrontal)ThickAvg': 1,
#          'lh_(cuneus)ThickAvg': 1,
#          'rh_(cuneus)ThickAvg': 1,
#          'lh_(entorhinal)ThickAvg': 1,
#          'rh_(entorhinal)ThickAvg': 1,
#          'rh_(fusiform)ThickAvg': 1,
#          'lh_(fusiform)ThickAvg': 1,
#          'lh_(inferiorparietal)ThickAvg': 1,
#          'rh_(inferiorparietal)ThickAvg': 1,
#          'lh_(inferiortemporal)ThickAvg': 1,
#          'rh_(inferiortemporal)ThickAvg': 1,
#          'lh_(insula)ThickAvg': 1,
#          'rh_(insula)ThickAvg': 1,
#          'lh_(isthmuscingulate)ThickAvg': 1,
#          'rh_(isthmuscingulate)ThickAvg': 1,
#          'lh_(lateraloccipital)ThickAvg': 1,
#          'rh_(lateraloccipital)ThickAvg': 1,
#          'lh_(lateralorbitofrontal)ThickAvg': 1,
#          'rh_(lateralorbitofrontal)ThickAvg': 1,
#          'lh_(lingual)ThickAvg': 1,
#          'rh_(lingual)ThickAvg': 1,
#          'lh_(medialorbitofrontal)ThickAvg': 1,
#          'rh_(medialorbitofrontal)ThickAvg': 1,
#          'lh_(middletemporal)ThickAvg': 1,
#          'rh_(middletemporal)ThickAvg': 1,
#          'lh_(paracentral)ThickAvg': 1,
#          'rh_(paracentral)ThickAvg': 1,
#          'lh_(parahippocampal)ThickAvg': 1,
#          'rh_(parahippocampal)ThickAvg': 1,
#          'lh_(parsopercularis)ThickAvg': 1,
#          'rh_(parsopercularis)ThickAvg': 1,
#          'lh_(parsorbitalis)ThickAvg': 1,
#          'rh_(parsorbitalis)ThickAvg': 1,
#          'lh_(parstriangularis)ThickAvg': 1,
#          'rh_(parstriangularis)ThickAvg': 1,
#          'lh_(pericalcarine)ThickAvg': 1,
#          'rh_(pericalcarine)ThickAvg': 1,
#          'lh_(postcentral)ThickAvg': 1,
#          'rh_(postcentral)ThickAvg': 1,
#          'lh_(posteriorcingulate)ThickAvg': 1,
#          'rh_(posteriorcingulate)ThickAvg': 1,
#          'lh_(precentral)ThickAvg': 1,
#          'rh_(precentral)ThickAvg': 1,
#          'lh_(precuneus)ThickAvg': 1,
#          'rh_(precuneus)ThickAvg': 1,
#          'lh_(rostralanteriorcingulate)ThickAvg': 1,
#          'rh_(rostralanteriorcingulate)ThickAvg': 1,
#          'lh_(rostralmiddlefrontal)ThickAvg': 1,
#          'rh_(rostralmiddlefrontal)ThickAvg': 1,
#          'lh_(superiorfrontal)ThickAvg': 1,
#          'rh_(superiorfrontal)ThickAvg': 1,
#          'lh_(superiorparietal)ThickAvg': 1,
#          'rh_(superiorparietal)ThickAvg': 1,
#          'lh_(superiortemporal)ThickAvg': 1,
#          'rh_(superiortemporal)ThickAvg': 1,
#          'lh_(supramarginal)ThickAvg': 1,
#          'rh_(supramarginal)ThickAvg': 1,
#          'lh_(transversetemporal)ThickAvg': 1,
#          'rh_(transversetemporal)ThickAvg': 1,
#          'lh_(precuneus)GrayVol': 1,
#          'rh_(precuneus)GrayVol': 1,
#          'lh_(transversetemporal)GrayVol': 1,
#          'rh_(transversetemporal)GrayVol': 1,
#          'rh_(parahippocampal)SurfArea': 1,
#          'rh_(paracentral)SurfArea': 1,
#          'rh_(parsopercularis)SurfArea': 1,
#          'rh_(parsorbitalis)SurfArea': 1,
#          'rh_(parstriangularis)SurfArea': 1,
#          'rh_(pericalcarine)SurfArea': 1,
#          'rh_(postcentral)SurfArea': 1,
#          'rh_(posteriorcingulate)SurfArea': 1,
#          'rh_(precentral)SurfArea': 1,
#          'rh_(precuneus)SurfArea': 1,
#          'rh_(rostralanteriorcingulate)SurfArea': 1,
#          'rh_(rostralmiddlefrontal)SurfArea': 1,
#          'rh_(superiorfrontal)SurfArea': 1,
#          'rh_(superiorparietal)SurfArea': 2,
#          'rh_(supramarginal)SurfArea': 1,
#          'rh_(temporalpole)SurfArea': 1,
#          'rh_(temporalpole)ThickAvg': 1,
#          'rh_(transversetemporal)SurfArea': 1,
#          '(Right-vessel)Volume_mm3': 1,
#          'lh_(insula)SurfArea': 1,
#          'rh_(insula)SurfArea': 1,
#          'lh_(bankssts)GrayVol': 1,
#          'lh_(bankssts)ThickAvg': 1,
#          'lh_(bankssts)SurfArea': 1,
#          'lh_(caudalanteriorcingulate)SurfArea': 1,
#          'lh_(caudalanteriorcingulate)GrayVol': 1,
#          'lh_(caudalmiddlefrontal)SurfArea': 1,
#          'lh_(cuneus)SurfArea': 1,
#          'lh_(entorhinal)SurfArea': 1,
#          'lh_(frontalpole)SurfArea': 1,
#          'lh_(frontalpole)ThickAvg': 1,
#          'lh_(fusiform)SurfArea': 1,
#          'lh_(inferiorparietal)SurfArea': 1,
#          'lh_(lateraloccipital)SurfArea': 1,
#          'lh_(lateralorbitofrontal)GrayVol': 1,
#          'lh_(lateralorbitofrontal)SurfArea': 1,
#          'lh_(lingual)SurfArea': 1,
#          'lh_(medialorbitofrontal)SurfArea': 1,
#          'lh_(middletemporal)SurfArea': 1,
#          'lh_(paracentral)SurfArea': 1,
#          'lh_(parahippocampal)SurfArea': 1,
#          'lh_(parsopercularis)SurfArea': 1,
#          'lh_(parsorbitalis)SurfArea': 1,
#          'lh_(parstriangularis)SurfArea': 1,
#          'lh_(pericalcarine)SurfArea': 1,
#          'lh_(postcentral)SurfArea': 1,
#          'lh_(posteriorcingulate)SurfArea': 1,
#          'lh_(precentral)SurfArea': 1,
#          'lh_(precuneus)SurfArea': 1,
#          'lh_(rostralanteriorcingulate)SurfArea': 1,
#          'lh_(rostralmiddlefrontal)SurfArea': 1,
#          'lh_(superiorfrontal)SurfArea': 1,
#          'lh_(superiorparietal)SurfArea': 1,
#          'lh_(superiortemporal)SurfArea': 1,
#          'lh_(supramarginal)SurfArea': 1,
#          'lh_(temporalpole)SurfArea': 1,
#          'lh_(temporalpole)ThickAvg': 1,
#          'lh_(transversetemporal)SurfArea': 1,
#          '(non-WM-hypointensities)Volume_mm3': 1,
#          '(Optic-Chiasm)Volume_mm3': 1,
#          'rh_(bankssts)GrayVol': 1,
#          'rh_(bankssts)ThickAvg': 1,
#          'rh_(bankssts)SurfArea': 1,
#          'rh_(caudalanteriorcingulate)GrayVol': 1,
#          'rh_(caudalanteriorcingulate)SurfArea': 1,
#          'rh_(caudalmiddlefrontal)SurfArea': 1,
#          'rh_(cuneus)SurfArea': 1,
#          'rh_(entorhinal)SurfArea': 1,
#          'rh_(frontalpole)ThickAvg': 1,
#          'rh_(frontalpole)SurfArea': 1,
#          'rh_(fusiform)SurfArea': 1,
#          'rh_(inferiorparietal)SurfArea': 1,
#          'rh_(inferiortemporal)SurfArea': 1,
#          'lh_(inferiortemporal)SurfArea': 1,
#          'rh_(isthmuscingulate)GrayVol': 1,
#          'lh_(isthmuscingulate)SurfArea': 1,
#          'rh_(lateraloccipital)SurfArea': 1,
#          'rh_(lateralorbitofrontal)SurfArea': 1,
#          'rh_(lateralorbitofrontal)GrayVol': 1,
#          'rh_(lingual)SurfArea': 1,
#          'rh_(medialorbitofrontal)SurfArea': 1,
#          'rh_(middletemporal)SurfArea': 1,
#          '(S_calcarine)GrayVol': 2,
#          '(CC_Posterior)Volume_mm3': 1,
#          '(CC_Mid_Posterior)Volume_mm3': 1,
#          '(CC_Central)Volume_mm3': 1,
#          '(CC_Mid_Anterior)Volume_mm3': 1,
#          '(CC_Anterior)Volume_mm3': 1,
#          'SubCortGrayVol': 1,
#          'SupraTentorialVol': 1,
#          '(G_and_S_frontomargin)SurfArea': 2,
#          '(G_and_S_occipital_inf)SurfArea': 2,
#          '(G_and_S_subcentral)SurfArea': 2,
#          '(G_and_S_transv_frontopol)SurfArea': 2,
#          '(G_and_S_cingul-Ant)SurfArea': 2,
#          '(G_and_S_cingul-Mid-Ant)SurfArea': 2,
#          '(G_and_S_cingul-Mid-Post)SurfArea': 2,
#          '(G_cingul-Post-dorsal)SurfArea': 2,
#          '(G_cingul-Post-ventral)SurfArea': 2,
#          '(G_cuneus)SurfArea': 2,
#          '(G_front_inf-Opercular)SurfArea': 2,
#          '(G_front_inf-Orbital)SurfArea': 2,
#          '(G_front_inf-Triangul)SurfArea': 2,
#          '(G_front_middle)SurfArea': 2,
#          '(G_front_sup)SurfArea': 2,
#          '(G_Ins_lg_and_S_cent_ins)SurfArea': 2,
#          '(G_insular_short)SurfArea': 2,
#          '(G_occipital_middle)SurfArea': 2,
#          '(G_occipital_sup)SurfArea': 2,
#          '(G_oc-temp_lat-fusifor)SurfArea': 2,
#          '(G_oc-temp_med-Lingual)SurfArea': 2,
#          '(G_oc-temp_med-Parahip)SurfArea': 2,
#          '(G_orbital)SurfArea': 2,
#          '(G_pariet_inf-Angular)SurfArea': 2,
#          '(G_pariet_inf-Supramar)SurfArea': 2,
#          '(G_parietal_sup)SurfArea': 2,
#          '(G_postcentral)SurfArea': 2,
#          '(G_precentral)SurfArea': 2,
#          '(G_precuneus)SurfArea': 2,
#          '(G_rectus)SurfArea': 2,
#          '(G_subcallosal)SurfArea': 2,
#          '(G_temp_sup-G_T_transv)SurfArea': 2,
#          '(G_temp_sup-Lateral)SurfArea': 2,
#          '(G_temp_sup-Plan_polar)SurfArea': 2,
#          '(G_temp_sup-Plan_tempo)SurfArea': 2,
#          '(G_temporal_inf)SurfArea': 2,
#          '(G_temporal_middle)SurfArea': 2,
#          '(Lat_Fis-ant-Horizont)SurfArea': 2,
#          '(Lat_Fis-ant-Vertical)SurfArea': 2,
#          '(Lat_Fis-post)SurfArea': 2,
#          '(Pole_occipital)SurfArea': 2,
#          '(Pole_temporal)SurfArea': 2,
#          '(S_calcarine)SurfArea': 2,
#          '(S_central)SurfArea': 2,
#          '(S_cingul-Marginalis)SurfArea': 2,
#          '(S_circular_insula_ant)SurfArea': 2,
#          '(S_circular_insula_inf)SurfArea': 2,
#          '(S_circular_insula_sup)SurfArea': 2,
#          '(S_collat_transv_ant)SurfArea': 2,
#          '(S_collat_transv_post)SurfArea': 2,
#          '(S_front_inf)SurfArea': 2,
#          '(S_front_middle)SurfArea': 2,
#          '(S_front_sup)SurfArea': 2,
#          '(S_interm_prim-Jensen)SurfArea': 2,
#          '(S_intrapariet_and_P_trans)SurfArea': 2,
#          '(S_oc_middle_and_Lunatus)SurfArea': 2,
#          '(S_oc_sup_and_transversal)SurfArea': 2,
#          '(S_occipital_ant)SurfArea': 2,
#          '(S_oc-temp_lat)SurfArea': 2,
#          '(S_oc-temp_med_and_Lingual)SurfArea': 2,
#          '(S_orbital_lateral)SurfArea': 2,
#          '(S_orbital_med-olfact)SurfArea': 2,
#          '(S_orbital-H_Shaped)SurfArea': 2,
#          '(S_parieto_occipital)SurfArea': 2,
#          '(S_pericallosal)SurfArea': 2,
#          '(S_postcentral)SurfArea': 2,
#          '(S_precentral-inf-part)SurfArea': 2,
#          '(S_precentral-sup-part)SurfArea': 2,
#          '(S_suborbital)SurfArea': 2,
#          '(S_subparietal)SurfArea': 2,
#          '(S_temporal_inf)SurfArea': 2,
#          '(S_temporal_sup)SurfArea': 2,
#          '(S_temporal_transverse)SurfArea': 2,
#          '(G_and_S_frontomargin)MeanCurv': 2,
#          '(G_and_S_occipital_inf)MeanCurv': 2,
#          '(G_and_S_paracentral)MeanCurv': 2,
#          '(G_and_S_subcentral)MeanCurv': 2,
#          '(G_and_S_transv_frontopol)MeanCurv': 2,
#          '(G_and_S_cingul-Ant)MeanCurv': 2,
#          '(G_and_S_cingul-Mid-Ant)MeanCurv': 2,
#          '(G_and_S_cingul-Mid-Post)MeanCurv': 2,
#          '(G_cingul-Post-dorsal)MeanCurv': 2,
#          '(G_cingul-Post-ventral)MeanCurv': 2,
#          '(G_cuneus)MeanCurv': 2,
#          '(G_Ins_lg_and_S_cent_ins)MeanCurv': 2,
#          '(G_orbital)MeanCurv': 2,
#          '(G_postcentral)MeanCurv': 2,
#          '(G_precentral)MeanCurv': 2,
#          '(G_precuneus)MeanCurv': 2,
#          '(G_rectus)MeanCurv': 2,
#          '(G_subcallosal)MeanCurv': 2,
#          '(G_temp_sup-G_T_transv)MeanCurv': 2,
#          '(G_temp_sup-Plan_polar)MeanCurv': 2,
#          '(G_temp_sup-Plan_tempo)MeanCurv': 2,
#          '(Lat_Fis-ant-Horizont)MeanCurv': 2,
#          '(Lat_Fis-ant-Vertical)MeanCurv': 2,
#          '(Lat_Fis-post)MeanCurv': 2,
#          '(Pole_occipital)MeanCurv': 2,
#          '(Pole_temporal)MeanCurv': 2,
#          '(S_calcarine)MeanCurv': 2,
#          '(S_central)MeanCurv': 2,
#          '(S_cingul-Marginalis)MeanCurv': 2,
#          '(S_circular_insula_ant)MeanCurv': 2,
#          '(S_circular_insula_inf)MeanCurv': 2,
#          '(S_circular_insula_sup)MeanCurv': 2,
#          '(S_collat_transv_ant)MeanCurv': 2,
#          '(S_collat_transv_post)MeanCurv': 2,
#          '(S_intrapariet_and_P_trans)MeanCurv': 2,
#          '(S_oc_middle_and_Lunatus)MeanCurv': 2,
#          '(S_oc_sup_and_transversal)MeanCurv': 2,
#          '(S_oc-temp_med_and_Lingual)MeanCurv': 2,
#          '(S_pericallosal)MeanCurv': 2,
#          '(S_precentral-inf-part)MeanCurv': 2,
#          '(S_precentral-sup-part)MeanCurv': 2,
#          '(S_suborbital)MeanCurv': 2,
#          '(S_subparietal)MeanCurv': 2,
#          '(G_and_S_frontomargin)ThickAvg': 2,
#          '(G_and_S_occipital_inf)ThickAvg': 2,
#          '(G_and_S_paracentral)ThickAvg': 2,
#          '(G_and_S_subcentral)ThickAvg': 2,
#          '(G_and_S_transv_frontopol)ThickAvg': 2,
#          '(G_and_S_cingul-Ant)ThickAvg': 2,
#          '(G_and_S_cingul-Mid-Ant)ThickAvg': 2,
#          '(G_and_S_cingul-Mid-Post)ThickAvg': 2,
#          '(G_cingul-Post-dorsal)ThickAvg': 2,
#          '(G_cingul-Post-ventral)ThickAvg': 2,
#          '(G_front_inf-Opercular)ThickAvg': 2,
#          '(G_front_inf-Orbital)ThickAvg': 2,
#          '(G_front_inf-Triangul)ThickAvg': 2,
#          '(G_front_middle)ThickAvg': 2,
#          '(G_front_sup)ThickAvg': 2,
#          '(G_Ins_lg_and_S_cent_ins)ThickAvg': 2,
#          '(G_insular_short)ThickAvg': 2,
#          '(G_occipital_middle)ThickAvg': 2,
#          '(G_occipital_sup)ThickAvg': 2,
#          '(G_oc-temp_lat-fusifor)ThickAvg': 2,
#          '(G_oc-temp_med-Lingual)ThickAvg': 2,
#          '(G_oc-temp_med-Parahip)ThickAvg': 2,
#          '(G_orbital)ThickAvg': 2,
#          '(G_pariet_inf-Angular)ThickAvg': 2,
#          '(G_pariet_inf-Supramar)ThickAvg': 2,
#          '(G_parietal_sup)ThickAvg': 2,
#          '(G_postcentral)ThickAvg': 2,
#          '(G_precentral)ThickAvg': 2,
#          '(G_precuneus)ThickAvg': 1,
#          '(G_rectus)ThickAvg': 2,
#          '(G_subcallosal)ThickAvg': 2,
#          '(G_temp_sup-G_T_transv)ThickAvg': 2,
#          '(G_temp_sup-Lateral)ThickAvg': 2,
#          '(G_temp_sup-Plan_polar)ThickAvg': 2,
#          '(G_temp_sup-Plan_tempo)ThickAvg': 2,
#          '(G_temporal_inf)ThickAvg': 2,
#          '(G_temporal_middle)ThickAvg': 2,
#          '(Lat_Fis-ant-Horizont)ThickAvg': 2,
#          '(Lat_Fis-ant-Vertical)ThickAvg': 2,
#          '(Lat_Fis-post)ThickAvg': 2,
#          '(Pole_occipital)ThickAvg': 2,
#          '(Pole_temporal)ThickAvg': 2,
#          '(S_calcarine)ThickAvg': 2,
#          '(S_central)ThickAvg': 2,
#          '(S_cingul-Marginalis)ThickAvg': 2,
#          '(S_circular_insula_ant)ThickAvg': 2,
#          '(S_circular_insula_inf)ThickAvg': 2,
#          '(S_circular_insula_sup)ThickAvg': 2,
#          '(S_collat_transv_ant)ThickAvg': 2,
#          '(S_collat_transv_post)ThickAvg': 2,
#          '(S_front_inf)ThickAvg': 2,
#          '(S_front_middle)ThickAvg': 2,
#          '(S_front_sup)ThickAvg': 2,
#          '(S_interm_prim-Jensen)ThickAvg': 2,
#          '(S_intrapariet_and_P_trans)ThickAvg': 2,
#          '(S_oc_middle_and_Lunatus)ThickAvg': 2,
#          '(S_oc_sup_and_transversal)ThickAvg': 2,
#          '(S_occipital_ant)ThickAvg': 2,
#          '(S_oc-temp_lat)ThickAvg': 2,
#          '(S_oc-temp_med_and_Lingual)ThickAvg': 2,
#          '(S_orbital_lateral)ThickAvg': 2,
#          '(S_orbital_med-olfact)ThickAvg': 2,
#          '(S_orbital-H_Shaped)ThickAvg': 2,
#          '(S_parieto_occipital)ThickAvg': 2,
#          '(S_pericallosal)ThickAvg': 2,
#          '(S_postcentral)ThickAvg': 2,
#          '(S_precentral-inf-part)ThickAvg': 2,
#          '(S_precentral-sup-part)ThickAvg': 2,
#          '(S_suborbital)ThickAvg': 2,
#          '(S_subparietal)ThickAvg': 2,
#          '(S_temporal_inf)ThickAvg': 2,
#          '(S_temporal_sup)ThickAvg': 2,
#          '(S_temporal_transverse)ThickAvg': 2,
#          '(G_and_S_frontomargin)GrayVol': 2,
#          '(G_and_S_occipital_inf)GrayVol': 2,
#          '(G_and_S_paracentral)GrayVol': 2,
#          '(G_and_S_subcentral)GrayVol': 2,
#          '(G_and_S_transv_frontopol)GrayVol': 2,
#          '(G_and_S_cingul-Ant)GrayVol': 2,
#          '(G_and_S_cingul-Mid-Ant)GrayVol': 2,
#          '(G_and_S_cingul-Mid-Post)GrayVol': 2,
#          '(G_cingul-Post-dorsal)GrayVol': 2,
#          '(G_cingul-Post-ventral)GrayVol': 2,
#          '(G_front_inf-Opercular)GrayVol': 2,
#          '(G_front_inf-Orbital)GrayVol': 2,
#          '(G_front_inf-Triangul)GrayVol': 2,
#          '(G_front_middle)GrayVol': 2,
#          '(G_front_sup)GrayVol': 2,
#          '(G_Ins_lg_and_S_cent_ins)GrayVol': 2,
#          '(G_insular_short)GrayVol': 2,
#          '(G_occipital_middle)GrayVol': 2,
#          '(G_occipital_sup)GrayVol': 2,
#          '(G_oc-temp_lat-fusifor)GrayVol': 2,
#          '(G_oc-temp_med-Lingual)GrayVol': 2,
#          '(G_oc-temp_med-Parahip)GrayVol': 2,
#          '(G_orbital)GrayVol': 2,
#          '(G_pariet_inf-Angular)GrayVol': 2,
#          '(G_pariet_inf-Supramar)GrayVol': 2,
#          '(G_parietal_sup)GrayVol': 2,
#          '(G_postcentral)GrayVol': 2,
#          '(G_precentral)GrayVol': 2,
#          '(G_precuneus)GrayVol': 2,
#          '(G_rectus)GrayVol': 2,
#          '(G_subcallosal)GrayVol': 2,
#          '(G_temp_sup-G_T_transv)GrayVol': 2,
#          '(G_temp_sup-Lateral)GrayVol': 2,
#          '(G_temp_sup-Plan_polar)GrayVol': 2,
#          '(G_temp_sup-Plan_tempo)GrayVol': 2,
#          '(G_temporal_inf)GrayVol': 2,
#          '(G_temporal_middle)GrayVol': 2,
#          '(Lat_Fis-ant-Horizont)GrayVol': 2,
#          '(Lat_Fis-ant-Vertical)GrayVol': 2,
#          '(Lat_Fis-post)GrayVol': 2,
#          '(S_central)GrayVol': 2,
#          '(S_cingul-Marginalis)GrayVol': 2,
#          '(S_circular_insula_ant)GrayVol': 2,
#          '(S_circular_insula_inf)GrayVol': 2,
#          '(S_circular_insula_sup)GrayVol': 2,
#          '(S_collat_transv_ant)GrayVol': 2,
#          '(S_collat_transv_post)GrayVol': 2,
#          '(S_front_inf)GrayVol': 2,
#          '(S_front_middle)GrayVol': 2,
#          '(S_front_sup)GrayVol': 2,
#          '(S_interm_prim-Jensen)GrayVol': 2,
#          '(S_intrapariet_and_P_trans)GrayVol': 2,
#          '(S_oc_middle_and_Lunatus)GrayVol': 2,
#          '(S_oc_sup_and_transversal)GrayVol': 2,
#          '(S_occipital_ant)GrayVol': 2,
#          '(S_oc-temp_lat)GrayVol': 2,
#          '(S_oc-temp_med_and_Lingual)GrayVol': 2,
#          '(S_orbital_lateral)GrayVol': 2,
#          '(S_orbital_med-olfact)GrayVol': 2,
#          '(S_orbital-H_Shaped)GrayVol': 2,
#          '(S_parieto_occipital)GrayVol': 2,
#          '(S_pericallosal)GrayVol': 2,
#          '(S_precentral-inf-part)GrayVol': 2,
#          '(S_precentral-sup-part)GrayVol': 2,
#          '(S_suborbital)GrayVol': 2,
#          '(S_subparietal)GrayVol': 2,
#          '(S_temporal_inf)GrayVol': 2,
#          '(S_temporal_sup)GrayVol': 2,
#          '(S_temporal_transverse)GrayVol': 2,
#          'lh_(bankssts)MeanCurv': 1,
#          'lh_(caudalanteriorcingulate)MeanCurv': 1,
#          'lh_(caudalmiddlefrontal)MeanCurv': 1,
#          'lh_(cuneus)MeanCurv': 1,
#          'lh_(entorhinal)MeanCurv': 1,
#          'rh_(fusiform)MeanCurv': 2,
#          'lh_(inferiorparietal)MeanCurv': 1,
#          'lh_(inferiortemporal)MeanCurv': 1,
#          'lh_(isthmuscingulate)MeanCurv': 1,
#          'lh_(lateraloccipital)MeanCurv': 1,
#          'lh_(lateralorbitofrontal)MeanCurv': 1,
#          'lh_(lingual)MeanCurv': 1,
#          'lh_(medialorbitofrontal)MeanCurv': 1,
#          'lh_(middletemporal)MeanCurv': 1,
#          'lh_(parahippocampal)MeanCurv': 1,
#          'lh_(paracentral)MeanCurv': 1,
#          'lh_(parsopercularis)MeanCurv': 1,
#          'lh_(parsorbitalis)MeanCurv': 1,
#          'lh_(parstriangularis)MeanCurv': 1,
#          'lh_(pericalcarine)MeanCurv': 1,
#          'lh_(postcentral)MeanCurv': 1,
#          'lh_(posteriorcingulate)MeanCurv': 2,
#          'lh_(precentral)MeanCurv': 1,
#          'lh_(precuneus)MeanCurv': 1,
#          'lh_(rostralanteriorcingulate)MeanCurv': 1,
#          'lh_(rostralmiddlefrontal)MeanCurv': 1,
#          'lh_(superiorfrontal)MeanCurv': 1,
#          'lh_(superiorparietal)MeanCurv': 1,
#          'lh_(superiortemporal)MeanCurv': 1,
#          'lh_(supramarginal)MeanCurv': 1,
#          'lh_(frontalpole)MeanCurv': 1,
#          'lh_(temporalpole)MeanCurv': 1,
#          'lh_(transversetemporal)MeanCurv': 1,
#          'lh_(insula)MeanCurv': 1,
#          '(G_and_S_paracentral)SurfArea': 2,
#          'lh_(isthmuscingulate)GrayVol': 1,
#          '(S_postcentral)MeanCurv': 1,
#          '(G_cuneus)ThickAvg': 1,
#          '(G_cuneus)GrayVol': 1,
#          '(S_postcentral)GrayVol': 1,
#          'rh_(isthmuscingulate)SurfArea': 1,
#          'rh_(bankssts)MeanCurv': 1,
#          'rh_(caudalanteriorcingulate)MeanCurv': 1,
#          'rh_(caudalmiddlefrontal)MeanCurv': 1,
#          'rh_(cuneus)MeanCurv': 1,
#          'rh_(entorhinal)MeanCurv': 1,
#          'rh_(inferiorparietal)MeanCurv': 1,
#          'rh_(inferiortemporal)MeanCurv': 1,
#          'rh_(isthmuscingulate)MeanCurv': 1,
#          'rh_(lateraloccipital)MeanCurv': 1,
#          'rh_(lateralorbitofrontal)MeanCurv': 1,
#          'rh_(lingual)MeanCurv': 1,
#          'rh_(medialorbitofrontal)MeanCurv': 1,
#          'rh_(middletemporal)MeanCurv': 1,
#          'rh_(parahippocampal)MeanCurv': 1,
#          'rh_(paracentral)MeanCurv': 1,
#          'rh_(parsopercularis)MeanCurv': 1,
#          'rh_(parsorbitalis)MeanCurv': 1,
#          'rh_(parstriangularis)MeanCurv': 1,
#          'rh_(pericalcarine)MeanCurv': 1,
#          'rh_(postcentral)MeanCurv': 1,
#          'rh_(precentral)MeanCurv': 1,
#          'rh_(precuneus)MeanCurv': 1,
#          'rh_(rostralanteriorcingulate)MeanCurv': 1,
#          'rh_(rostralmiddlefrontal)MeanCurv': 1,
#          'rh_(superiorfrontal)MeanCurv': 1,
#          'rh_(superiorparietal)MeanCurv': 1,
#          'rh_(superiortemporal)MeanCurv': 1,
#          'rh_(supramarginal)MeanCurv': 1,
#          'rh_(frontalpole)MeanCurv': 1,
#          'rh_(temporalpole)MeanCurv': 1,
#          'rh_(transversetemporal)MeanCurv': 1,
#          'rh_(insula)MeanCurv': 1,
#          'PET score': 1,
#          'MeanCortex': 1,
#          '(Left-Inf-Lat-Vent)Volume_mm3': 1,
#          '(Left-Lateral-Ventricle)Volume_mm3': 1,
#          '(Right-Inf-Lat-Vent)Volume_mm3': 1,
#          '(Right-Lateral-Ventricle)Volume_mm3': 1,
#          '(3rd-Ventricle)Volume_mm3': 1,
#          '(5th-Ventricle)Volume_mm3': 1,
#          '(Left-Hippocampus)Volume_mm3': 1,
#          '(Right-Hippocampus)Volume_mm3': 1})

# %%
for i in features_all['JADNI'].dropna().to_list():
    if i not in cohort_studies['JADNI'].columns:
        print(i)
# Out:
# (Pole_occipital)GrayVol
# (Pole_temporal)GrayVol
# (Pole_occipital)GrayVol
# (Pole_temporal)GrayVol
# (S_calcarine)GrayVol
# (S_calcarine)GrayVol
# (G_and_S_frontomargin)SurfArea
# (G_and_S_occipital_inf)SurfArea
# (G_and_S_subcentral)SurfArea
# (G_and_S_transv_frontopol)SurfArea
# (G_and_S_cingul-Ant)SurfArea
# (G_and_S_cingul-Mid-Ant)SurfArea
# (G_and_S_cingul-Mid-Post)SurfArea
# (G_cingul-Post-dorsal)SurfArea
# (G_cingul-Post-ventral)SurfArea
# (G_cuneus)SurfArea
# (G_front_inf-Opercular)SurfArea
# (G_front_inf-Orbital)SurfArea
# (G_front_inf-Triangul)SurfArea
# (G_front_middle)SurfArea
# (G_front_sup)SurfArea
# (G_Ins_lg_and_S_cent_ins)SurfArea
# (G_insular_short)SurfArea
# (G_occipital_middle)SurfArea
# (G_occipital_sup)SurfArea
# (G_oc-temp_lat-fusifor)SurfArea
# (G_oc-temp_med-Lingual)SurfArea
# (G_oc-temp_med-Parahip)SurfArea
# (G_orbital)SurfArea
# (G_pariet_inf-Angular)SurfArea
# (G_pariet_inf-Supramar)SurfArea
# (G_parietal_sup)SurfArea
# (G_postcentral)SurfArea
# (G_precentral)SurfArea
# (G_precuneus)SurfArea
# (G_rectus)SurfArea
# (G_subcallosal)SurfArea
# (G_temp_sup-G_T_transv)SurfArea
# (G_temp_sup-Lateral)SurfArea
# (G_temp_sup-Plan_polar)SurfArea
# (G_temp_sup-Plan_tempo)SurfArea
# (G_temporal_inf)SurfArea
# (G_temporal_middle)SurfArea
# (Lat_Fis-ant-Horizont)SurfArea
# (Lat_Fis-ant-Vertical)SurfArea
# (Lat_Fis-post)SurfArea
# (Pole_occipital)SurfArea
# (Pole_temporal)SurfArea
# (S_calcarine)SurfArea
# (S_central)SurfArea
# (S_cingul-Marginalis)SurfArea
# (S_circular_insula_ant)SurfArea
# (S_circular_insula_inf)SurfArea
# (S_circular_insula_sup)SurfArea
# (S_collat_transv_ant)SurfArea
# (S_collat_transv_post)SurfArea
# (S_front_inf)SurfArea
# (S_front_middle)SurfArea
# (S_front_sup)SurfArea
# (S_interm_prim-Jensen)SurfArea
# (S_intrapariet_and_P_trans)SurfArea
# (S_oc_middle_and_Lunatus)SurfArea
# (S_oc_sup_and_transversal)SurfArea
# (S_occipital_ant)SurfArea
# (S_oc-temp_lat)SurfArea
# (S_oc-temp_med_and_Lingual)SurfArea
# (S_orbital_lateral)SurfArea
# (S_orbital_med-olfact)SurfArea
# (S_orbital-H_Shaped)SurfArea
# (S_parieto_occipital)SurfArea
# (S_pericallosal)SurfArea
# (S_postcentral)SurfArea
# (S_precentral-inf-part)SurfArea
# (S_precentral-sup-part)SurfArea
# (S_suborbital)SurfArea
# (S_subparietal)SurfArea
# (S_temporal_inf)SurfArea
# (S_temporal_sup)SurfArea
# (S_temporal_transverse)SurfArea
# (G_and_S_frontomargin)MeanCurv
# (G_and_S_occipital_inf)MeanCurv
# (G_and_S_paracentral)MeanCurv
# (G_and_S_subcentral)MeanCurv
# (G_and_S_transv_frontopol)MeanCurv
# (G_and_S_cingul-Ant)MeanCurv
# (G_and_S_cingul-Mid-Ant)MeanCurv
# (G_and_S_cingul-Mid-Post)MeanCurv
# (G_cingul-Post-dorsal)MeanCurv
# (G_cingul-Post-ventral)MeanCurv
# (G_cuneus)MeanCurv
# (G_Ins_lg_and_S_cent_ins)MeanCurv
# (G_orbital)MeanCurv
# (G_postcentral)MeanCurv
# (G_precentral)MeanCurv
# (G_precuneus)MeanCurv
# (G_rectus)MeanCurv
# (G_subcallosal)MeanCurv
# (G_temp_sup-G_T_transv)MeanCurv
# (G_temp_sup-Plan_polar)MeanCurv
# (G_temp_sup-Plan_tempo)MeanCurv
# (Lat_Fis-ant-Horizont)MeanCurv
# (Lat_Fis-ant-Vertical)MeanCurv
# (Lat_Fis-post)MeanCurv
# (Pole_occipital)MeanCurv
# (Pole_temporal)MeanCurv
# (S_calcarine)MeanCurv
# (S_central)MeanCurv
# (S_cingul-Marginalis)MeanCurv
# (S_circular_insula_ant)MeanCurv
# (S_circular_insula_inf)MeanCurv
# (S_circular_insula_sup)MeanCurv
# (S_collat_transv_ant)MeanCurv
# (S_collat_transv_post)MeanCurv
# (S_intrapariet_and_P_trans)MeanCurv
# (S_oc_middle_and_Lunatus)MeanCurv
# (S_oc_sup_and_transversal)MeanCurv
# (S_oc-temp_med_and_Lingual)MeanCurv
# (S_pericallosal)MeanCurv
# (S_precentral-inf-part)MeanCurv
# (S_precentral-sup-part)MeanCurv
# (S_suborbital)MeanCurv
# (S_subparietal)MeanCurv
# (G_and_S_frontomargin)ThickAvg
# (G_and_S_occipital_inf)ThickAvg
# (G_and_S_paracentral)ThickAvg
# (G_and_S_subcentral)ThickAvg
# (G_and_S_transv_frontopol)ThickAvg
# (G_and_S_cingul-Ant)ThickAvg
# (G_and_S_cingul-Mid-Ant)ThickAvg
# (G_and_S_cingul-Mid-Post)ThickAvg
# (G_cingul-Post-dorsal)ThickAvg
# (G_cingul-Post-ventral)ThickAvg
# (G_front_inf-Opercular)ThickAvg
# (G_front_inf-Orbital)ThickAvg
# (G_front_inf-Triangul)ThickAvg
# (G_front_middle)ThickAvg
# (G_front_sup)ThickAvg
# (G_Ins_lg_and_S_cent_ins)ThickAvg
# (G_insular_short)ThickAvg
# (G_occipital_middle)ThickAvg
# (G_occipital_sup)ThickAvg
# (G_oc-temp_lat-fusifor)ThickAvg
# (G_oc-temp_med-Lingual)ThickAvg
# (G_oc-temp_med-Parahip)ThickAvg
# (G_orbital)ThickAvg
# (G_pariet_inf-Angular)ThickAvg
# (G_pariet_inf-Supramar)ThickAvg
# (G_parietal_sup)ThickAvg
# (G_postcentral)ThickAvg
# (G_precentral)ThickAvg
# (G_precuneus)ThickAvg
# (G_rectus)ThickAvg
# (G_subcallosal)ThickAvg
# (G_temp_sup-G_T_transv)ThickAvg
# (G_temp_sup-Lateral)ThickAvg
# (G_temp_sup-Plan_polar)ThickAvg
# (G_temp_sup-Plan_tempo)ThickAvg
# (G_temporal_inf)ThickAvg
# (G_temporal_middle)ThickAvg
# (Lat_Fis-ant-Horizont)ThickAvg
# (Lat_Fis-ant-Vertical)ThickAvg
# (Lat_Fis-post)ThickAvg
# (Pole_occipital)ThickAvg
# (Pole_temporal)ThickAvg
# (S_calcarine)ThickAvg
# (S_central)ThickAvg
# (S_cingul-Marginalis)ThickAvg
# (S_circular_insula_ant)ThickAvg
# (S_circular_insula_inf)ThickAvg
# (S_circular_insula_sup)ThickAvg
# (S_collat_transv_ant)ThickAvg
# (S_collat_transv_post)ThickAvg
# (S_front_inf)ThickAvg
# (S_front_middle)ThickAvg
# (S_front_sup)ThickAvg
# (S_interm_prim-Jensen)ThickAvg
# (S_intrapariet_and_P_trans)ThickAvg
# (S_oc_middle_and_Lunatus)ThickAvg
# (S_oc_sup_and_transversal)ThickAvg
# (S_occipital_ant)ThickAvg
# (S_oc-temp_lat)ThickAvg
# (S_oc-temp_med_and_Lingual)ThickAvg
# (S_orbital_lateral)ThickAvg
# (S_orbital_med-olfact)ThickAvg
# (S_orbital-H_Shaped)ThickAvg
# (S_parieto_occipital)ThickAvg
# (S_pericallosal)ThickAvg
# (S_postcentral)ThickAvg
# (S_precentral-inf-part)ThickAvg
# (S_precentral-sup-part)ThickAvg
# (S_suborbital)ThickAvg
# (S_subparietal)ThickAvg
# (S_temporal_inf)ThickAvg
# (S_temporal_sup)ThickAvg
# (S_temporal_transverse)ThickAvg
# (G_and_S_frontomargin)GrayVol
# (G_and_S_occipital_inf)GrayVol
# (G_and_S_paracentral)GrayVol
# (G_and_S_subcentral)GrayVol
# (G_and_S_transv_frontopol)GrayVol
# (G_and_S_cingul-Ant)GrayVol
# (G_and_S_cingul-Mid-Ant)GrayVol
# (G_and_S_cingul-Mid-Post)GrayVol
# (G_cingul-Post-dorsal)GrayVol
# (G_cingul-Post-ventral)GrayVol
# (G_front_inf-Opercular)GrayVol
# (G_front_inf-Orbital)GrayVol
# (G_front_inf-Triangul)GrayVol
# (G_front_middle)GrayVol
# (G_front_sup)GrayVol
# (G_Ins_lg_and_S_cent_ins)GrayVol
# (G_insular_short)GrayVol
# (G_occipital_middle)GrayVol
# (G_occipital_sup)GrayVol
# (G_oc-temp_lat-fusifor)GrayVol
# (G_oc-temp_med-Lingual)GrayVol
# (G_oc-temp_med-Parahip)GrayVol
# (G_orbital)GrayVol
# (G_pariet_inf-Angular)GrayVol
# (G_pariet_inf-Supramar)GrayVol
# (G_parietal_sup)GrayVol
# (G_postcentral)GrayVol
# (G_precentral)GrayVol
# (G_precuneus)GrayVol
# (G_rectus)GrayVol
# (G_subcallosal)GrayVol
# (G_temp_sup-G_T_transv)GrayVol
# (G_temp_sup-Lateral)GrayVol
# (G_temp_sup-Plan_polar)GrayVol
# (G_temp_sup-Plan_tempo)GrayVol
# (G_temporal_inf)GrayVol
# (G_temporal_middle)GrayVol
# (Lat_Fis-ant-Horizont)GrayVol
# (Lat_Fis-ant-Vertical)GrayVol
# (Lat_Fis-post)GrayVol
# (S_central)GrayVol
# (S_cingul-Marginalis)GrayVol
# (S_circular_insula_ant)GrayVol
# (S_circular_insula_inf)GrayVol
# (S_circular_insula_sup)GrayVol
# (S_collat_transv_ant)GrayVol
# (S_collat_transv_post)GrayVol
# (S_front_inf)GrayVol
# (S_front_middle)GrayVol
# (S_front_sup)GrayVol
# (S_interm_prim-Jensen)GrayVol
# (S_intrapariet_and_P_trans)GrayVol
# (S_oc_middle_and_Lunatus)GrayVol
# (S_oc_sup_and_transversal)GrayVol
# (S_occipital_ant)GrayVol
# (S_oc-temp_lat)GrayVol
# (S_oc-temp_med_and_Lingual)GrayVol
# (S_orbital_lateral)GrayVol
# (S_orbital_med-olfact)GrayVol
# (S_orbital-H_Shaped)GrayVol
# (S_parieto_occipital)GrayVol
# (S_pericallosal)GrayVol
# (S_precentral-inf-part)GrayVol
# (S_precentral-sup-part)GrayVol
# (S_suborbital)GrayVol
# (S_subparietal)GrayVol
# (S_temporal_inf)GrayVol
# (S_temporal_sup)GrayVol
# (S_temporal_transverse)GrayVol
# (G_and_S_paracentral)SurfArea
# (G_and_S_frontomargin)SurfArea
# (G_and_S_occipital_inf)SurfArea
# (G_and_S_paracentral)SurfArea
# (G_and_S_subcentral)SurfArea
# (G_and_S_transv_frontopol)SurfArea
# (G_and_S_cingul-Ant)SurfArea
# (G_and_S_cingul-Mid-Ant)SurfArea
# (G_and_S_cingul-Mid-Post)SurfArea
# (G_cingul-Post-dorsal)SurfArea
# (G_cingul-Post-ventral)SurfArea
# (G_cuneus)SurfArea
# (G_front_inf-Opercular)SurfArea
# (G_front_inf-Orbital)SurfArea
# (G_front_inf-Triangul)SurfArea
# (G_front_middle)SurfArea
# (G_front_sup)SurfArea
# (G_Ins_lg_and_S_cent_ins)SurfArea
# (G_insular_short)SurfArea
# (G_occipital_middle)SurfArea
# (G_occipital_sup)SurfArea
# (G_oc-temp_lat-fusifor)SurfArea
# (G_oc-temp_med-Lingual)SurfArea
# (G_oc-temp_med-Parahip)SurfArea
# (G_orbital)SurfArea
# (G_pariet_inf-Angular)SurfArea
# (G_pariet_inf-Supramar)SurfArea
# (G_parietal_sup)SurfArea
# (G_postcentral)SurfArea
# (G_precentral)SurfArea
# (G_precuneus)SurfArea
# (G_rectus)SurfArea
# (G_subcallosal)SurfArea
# (G_temp_sup-G_T_transv)SurfArea
# (G_temp_sup-Lateral)SurfArea
# (G_temp_sup-Plan_polar)SurfArea
# (G_temp_sup-Plan_tempo)SurfArea
# (G_temporal_inf)SurfArea
# (G_temporal_middle)SurfArea
# (Lat_Fis-ant-Horizont)SurfArea
# (Lat_Fis-ant-Vertical)SurfArea
# (Lat_Fis-post)SurfArea
# (Pole_occipital)SurfArea
# (Pole_temporal)SurfArea
# (S_calcarine)SurfArea
# (S_central)SurfArea
# (S_cingul-Marginalis)SurfArea
# (S_circular_insula_ant)SurfArea
# (S_circular_insula_inf)SurfArea
# (S_circular_insula_sup)SurfArea
# (S_collat_transv_ant)SurfArea
# (S_collat_transv_post)SurfArea
# (S_front_inf)SurfArea
# (S_front_middle)SurfArea
# (S_front_sup)SurfArea
# (S_interm_prim-Jensen)SurfArea
# (S_intrapariet_and_P_trans)SurfArea
# (S_oc_middle_and_Lunatus)SurfArea
# (S_oc_sup_and_transversal)SurfArea
# (S_occipital_ant)SurfArea
# (S_oc-temp_lat)SurfArea
# (S_oc-temp_med_and_Lingual)SurfArea
# (S_orbital_lateral)SurfArea
# (S_orbital_med-olfact)SurfArea
# (S_orbital-H_Shaped)SurfArea
# (S_parieto_occipital)SurfArea
# (S_pericallosal)SurfArea
# (S_postcentral)SurfArea
# (S_precentral-inf-part)SurfArea
# (S_precentral-sup-part)SurfArea
# (S_suborbital)SurfArea
# (S_subparietal)SurfArea
# (S_temporal_inf)SurfArea
# (S_temporal_sup)SurfArea
# (S_temporal_transverse)SurfArea
# (G_and_S_frontomargin)MeanCurv
# (G_and_S_occipital_inf)MeanCurv
# (G_and_S_paracentral)MeanCurv
# (G_and_S_subcentral)MeanCurv
# (G_and_S_transv_frontopol)MeanCurv
# (G_and_S_cingul-Ant)MeanCurv
# (G_and_S_cingul-Mid-Ant)MeanCurv
# (G_and_S_cingul-Mid-Post)MeanCurv
# (G_cingul-Post-dorsal)MeanCurv
# (G_cingul-Post-ventral)MeanCurv
# (G_cuneus)MeanCurv
# (G_Ins_lg_and_S_cent_ins)MeanCurv
# (G_orbital)MeanCurv
# (G_postcentral)MeanCurv
# (G_precentral)MeanCurv
# (G_precuneus)MeanCurv
# (G_rectus)MeanCurv
# (G_subcallosal)MeanCurv
# (G_temp_sup-G_T_transv)MeanCurv
# (G_temp_sup-Plan_polar)MeanCurv
# (G_temp_sup-Plan_tempo)MeanCurv
# (Lat_Fis-ant-Horizont)MeanCurv
# (Lat_Fis-ant-Vertical)MeanCurv
# (Lat_Fis-post)MeanCurv
# (Pole_occipital)MeanCurv
# (Pole_temporal)MeanCurv
# (S_calcarine)MeanCurv
# (S_central)MeanCurv
# (S_cingul-Marginalis)MeanCurv
# (S_circular_insula_ant)MeanCurv
# (S_circular_insula_inf)MeanCurv
# (S_circular_insula_sup)MeanCurv
# (S_collat_transv_ant)MeanCurv
# (S_collat_transv_post)MeanCurv
# (S_intrapariet_and_P_trans)MeanCurv
# (S_oc_middle_and_Lunatus)MeanCurv
# (S_oc_sup_and_transversal)MeanCurv
# (S_oc-temp_med_and_Lingual)MeanCurv
# (S_pericallosal)MeanCurv
# (S_postcentral)MeanCurv
# (S_precentral-inf-part)MeanCurv
# (S_precentral-sup-part)MeanCurv
# (S_suborbital)MeanCurv
# (S_subparietal)MeanCurv
# (G_and_S_frontomargin)ThickAvg
# (G_and_S_occipital_inf)ThickAvg
# (G_and_S_paracentral)ThickAvg
# (G_and_S_subcentral)ThickAvg
# (G_and_S_transv_frontopol)ThickAvg
# (G_and_S_cingul-Ant)ThickAvg
# (G_and_S_cingul-Mid-Ant)ThickAvg
# (G_and_S_cingul-Mid-Post)ThickAvg
# (G_cingul-Post-dorsal)ThickAvg
# (G_cingul-Post-ventral)ThickAvg
# (G_cuneus)ThickAvg
# (G_front_inf-Opercular)ThickAvg
# (G_front_inf-Orbital)ThickAvg
# (G_front_inf-Triangul)ThickAvg
# (G_front_middle)ThickAvg
# (G_front_sup)ThickAvg
# (G_Ins_lg_and_S_cent_ins)ThickAvg
# (G_insular_short)ThickAvg
# (G_occipital_middle)ThickAvg
# (G_occipital_sup)ThickAvg
# (G_oc-temp_lat-fusifor)ThickAvg
# (G_oc-temp_med-Lingual)ThickAvg
# (G_oc-temp_med-Parahip)ThickAvg
# (G_orbital)ThickAvg
# (G_pariet_inf-Angular)ThickAvg
# (G_pariet_inf-Supramar)ThickAvg
# (G_parietal_sup)ThickAvg
# (G_postcentral)ThickAvg
# (G_precentral)ThickAvg
# (G_rectus)ThickAvg
# (G_subcallosal)ThickAvg
# (G_temp_sup-G_T_transv)ThickAvg
# (G_temp_sup-Lateral)ThickAvg
# (G_temp_sup-Plan_polar)ThickAvg
# (G_temp_sup-Plan_tempo)ThickAvg
# (G_temporal_inf)ThickAvg
# (G_temporal_middle)ThickAvg
# (Lat_Fis-ant-Horizont)ThickAvg
# (Lat_Fis-ant-Vertical)ThickAvg
# (Lat_Fis-post)ThickAvg
# (Pole_occipital)ThickAvg
# (Pole_temporal)ThickAvg
# (S_calcarine)ThickAvg
# (S_central)ThickAvg
# (S_cingul-Marginalis)ThickAvg
# (S_circular_insula_ant)ThickAvg
# (S_circular_insula_inf)ThickAvg
# (S_circular_insula_sup)ThickAvg
# (S_collat_transv_ant)ThickAvg
# (S_collat_transv_post)ThickAvg
# (S_front_inf)ThickAvg
# (S_front_middle)ThickAvg
# (S_front_sup)ThickAvg
# (S_interm_prim-Jensen)ThickAvg
# (S_intrapariet_and_P_trans)ThickAvg
# (S_oc_middle_and_Lunatus)ThickAvg
# (S_oc_sup_and_transversal)ThickAvg
# (S_occipital_ant)ThickAvg
# (S_oc-temp_lat)ThickAvg
# (S_oc-temp_med_and_Lingual)ThickAvg
# (S_orbital_lateral)ThickAvg
# (S_orbital_med-olfact)ThickAvg
# (S_orbital-H_Shaped)ThickAvg
# (S_parieto_occipital)ThickAvg
# (S_pericallosal)ThickAvg
# (S_postcentral)ThickAvg
# (S_precentral-inf-part)ThickAvg
# (S_precentral-sup-part)ThickAvg
# (S_suborbital)ThickAvg
# (S_subparietal)ThickAvg
# (S_temporal_inf)ThickAvg
# (S_temporal_sup)ThickAvg
# (S_temporal_transverse)ThickAvg
# (G_and_S_frontomargin)GrayVol
# (G_and_S_occipital_inf)GrayVol
# (G_and_S_paracentral)GrayVol
# (G_and_S_subcentral)GrayVol
# (G_and_S_transv_frontopol)GrayVol
# (G_and_S_cingul-Ant)GrayVol
# (G_and_S_cingul-Mid-Ant)GrayVol
# (G_and_S_cingul-Mid-Post)GrayVol
# (G_cingul-Post-dorsal)GrayVol
# (G_cingul-Post-ventral)GrayVol
# (G_cuneus)GrayVol
# (G_front_inf-Opercular)GrayVol
# (G_front_inf-Orbital)GrayVol
# (G_front_inf-Triangul)GrayVol
# (G_front_middle)GrayVol
# (G_front_sup)GrayVol
# (G_Ins_lg_and_S_cent_ins)GrayVol
# (G_insular_short)GrayVol
# (G_occipital_middle)GrayVol
# (G_occipital_sup)GrayVol
# (G_oc-temp_lat-fusifor)GrayVol
# (G_oc-temp_med-Lingual)GrayVol
# (G_oc-temp_med-Parahip)GrayVol
# (G_orbital)GrayVol
# (G_pariet_inf-Angular)GrayVol
# (G_pariet_inf-Supramar)GrayVol
# (G_parietal_sup)GrayVol
# (G_postcentral)GrayVol
# (G_precentral)GrayVol
# (G_precuneus)GrayVol
# (G_rectus)GrayVol
# (G_subcallosal)GrayVol
# (G_temp_sup-G_T_transv)GrayVol
# (G_temp_sup-Lateral)GrayVol
# (G_temp_sup-Plan_polar)GrayVol
# (G_temp_sup-Plan_tempo)GrayVol
# (G_temporal_inf)GrayVol
# (G_temporal_middle)GrayVol
# (Lat_Fis-ant-Horizont)GrayVol
# (Lat_Fis-ant-Vertical)GrayVol
# (Lat_Fis-post)GrayVol
# (S_central)GrayVol
# (S_cingul-Marginalis)GrayVol
# (S_circular_insula_ant)GrayVol
# (S_circular_insula_inf)GrayVol
# (S_circular_insula_sup)GrayVol
# (S_collat_transv_ant)GrayVol
# (S_collat_transv_post)GrayVol
# (S_front_inf)GrayVol
# (S_front_middle)GrayVol
# (S_front_sup)GrayVol
# (S_interm_prim-Jensen)GrayVol
# (S_intrapariet_and_P_trans)GrayVol
# (S_oc_middle_and_Lunatus)GrayVol
# (S_oc_sup_and_transversal)GrayVol
# (S_occipital_ant)GrayVol
# (S_oc-temp_lat)GrayVol
# (S_oc-temp_med_and_Lingual)GrayVol
# (S_orbital_lateral)GrayVol
# (S_orbital_med-olfact)GrayVol
# (S_orbital-H_Shaped)GrayVol
# (S_parieto_occipital)GrayVol
# (S_pericallosal)GrayVol
# (S_postcentral)GrayVol
# (S_precentral-inf-part)GrayVol
# (S_precentral-sup-part)GrayVol
# (S_suborbital)GrayVol
# (S_subparietal)GrayVol
# (S_temporal_inf)GrayVol
# (S_temporal_sup)GrayVol
# (S_temporal_transverse)GrayVol

# %%
def umap_atn_participants(dfss, cohorts, thresholds, features):
    """cohorts: list of cohort names 
       dfss: dictionary of cohorts where each key is the name of a cohort
       thresholds: cutoff values obtained using a methodology
       
       Select the features and participants and categorize the participant into ATN profiles using thresholds
       obtained from each methodology.
       
       return a df which contain the combination of paticipant from the selected cohorts while harmonizing
       the features names.
    """
    
    # make a list of additional features to be investigated 
    additional_feat = ['Age', 'Sex', 'Education', 'APOE4', 'CDR', 'Race']
    # make an empty dictionary to add the datasets to
    df_= pd.DataFrame(columns=set(features.loc[features['Rank']==0]
                                  [cohorts + ['Feature']].dropna()['Feature']).difference(['Feature'] + list(thresholds.columns)).union(additional_feat))
   
    for i in cohorts:
        dfs = dict()
        dfs[i] = dfss[i].copy() # make a copy of the dataset of interest
        # select the subset of datasets with features to be investigated
        dfs[i] = dfs[i][features.loc[features['Rank']==0][cohorts + ['Feature']].dropna()[i].to_list() + additional_feat].dropna(axis=1, how='all')
        # rename all the columns so we can concat the datasets later
        [dfs[i].rename(columns={col: coln}, inplace=True) for col, coln in 
         zip(features.loc[features['Rank']==0][cohorts + ['Feature']].dropna()[i].to_list(), 
             features.loc[features['Rank']==0][cohorts + ['Feature']].dropna()['Feature'].to_list())]
        dfs[i]['Cohort'] = i # add a cohort name column
        # change the datatype to str as these are categorical features. astype doesn't work as it will include nan values
        dfs[i] = dfs[i].replace({'CDR': {0.0: '0', 0.5: '0.5', 1.0: '1', 2.0: '2'}, 
                                               'APOE4': {0.0: '0', 2.0: '2', 1.0: '1'}}) 
        
        for biomarker in thresholds.columns:
            # select the cutoff value for each biomarker for each cohort
            threshold = thresholds.loc[i][biomarker]
            
            # dichotomize the participants
            if biomarker == 'pTau in CSF': 
                dfs[i].loc[dfs[i][biomarker]>threshold, "T"] = 'T+'
                dfs[i].loc[dfs[i][biomarker]<threshold, "T"] = 'T-'
            
            elif biomarker == 'tTau in CSF': 
                dfs[i].loc[dfs[i][biomarker]>threshold, "N"] = 'N+'
                dfs[i].loc[dfs[i][biomarker]<threshold, "N"] = 'N-'
                
            else: 
                dfs[i].loc[dfs[i][biomarker]<threshold, "A"] = 'A+'
                dfs[i].loc[dfs[i][biomarker]>threshold, "A"] = 'A-'
                
        # join the 3 columns to make the final ATN categorie                                 
        dfs[i]['ATN'] = dfs[i]['A'] + dfs[i]['T'] + dfs[i]['N']
        # remove the columns that we are not interested in
        dfs[i] = dfs[i][dfs[i].columns.difference(['A', 'T', 'N'] + list(thresholds.columns))]
        
#         print(Counter(df_.columns))
#         print(Counter(dfs[i].columns))
#         print(dfs[i].columns.intersection(df_.columns))
#         print(len(dfs[i].columns.difference(df_.columns)))

        
        df_ = pd.concat([df_, dfs[i]])
    
    df_ = df_.dropna(axis=1, how='all')
    df_ = df_.dropna()

    return df_

# %%
test_df = umap_atn_participants(cohort_studies, ['ADNI', 'EPAD'], cutoffs_['gmm_cutoffs'], features_all)

# %%
# umap_atn_participants(cohort_studies, ['DOD-ADNI', 'JADNI'], cutoffs_['gmm_cutoffs'], features_all)

# umap_atn_participants(cohort_studies, ['DOD-ADNI', 'EPAD'], cutoffs_['gmm_cutoffs'], features_all)

# %%
def norm_df(df, cohorts_l):
    """df: concatenated df, containing participants of interested cohort studies
    cohorts_l: a list of cohorts that are contain in the df
    normalize the continuous features and apply dummy variable method for categorical features
    return: a dictionary where the keys are the cohort name and the values are dfs containing preprocessed values 
    """
    cohort_dict = dict()
    for i in cohorts_l:
        sub_df = df.loc[df['Cohort']==i]
        # make dummy variables and normalize features 
        num = sub_df[sub_df.select_dtypes(exclude='object').columns.difference(['APOE4', 'CDR'])].apply(stats.zscore)
        cat = pd.get_dummies(sub_df[sub_df.select_dtypes(include='object').columns.difference(['ATN', 'Cohort'])].dropna())
        others = sub_df[['ATN', 'Cohort']]
        data_f = pd.concat([num, cat, others], axis=1)
        cohort_dict[i] = data_f
    return cohort_dict

# %%
norm_df(test_df, ['ADNI', 'EPAD'])['ADNI']
# Out:
#            Age  Cerebrospinal Fluid Volume  \
# 1002  0.421515                   -0.012880
# 1009  0.352158                    0.519244
# 1010  0.130216                    0.216751
# 1013  0.629586                    0.077647
# 1016  0.698942                   -1.573925
# ...        ...                         ...
# 972   0.643457                   -0.659819
# 973   0.490872                   -0.121071
# 978  -0.022370                    0.294030
# 97   -0.063984                    0.954217
# 994  -2.519219                   -1.297927
#
#       Clinical Dementia Rating Scale Sum of Boxes (CDRSB)  Education  \
# 1002                                          -0.940882     0.748523
# 1009                                          -0.940882     0.009765
# 1010                                          -0.399859     1.487281
# 1013                                          -0.940882     1.487281
# 1016                                          -0.940882    -1.098372
# ...                                                 ...          ...
# 972                                           -0.940882     0.009765
# 973                                            0.141163     1.487281
# 978                                           -0.129348    -1.467751
# 97                                            -0.940882    -0.728993
# 994                                            0.141163     0.748523
#
#       Fourth Ventricle Volume  Geriatric Depression Scale (GDS)  \
# 1002                -1.042671                          0.385249
# 1009                -0.422266                         -0.330919
# 1010                 0.986143                          1.101417
# 1013                 0.302521                          0.385249
# 1016                -1.314650                         -0.330919
# ...                       ...                               ...
# 972                 -0.092951                         -1.047087
# 973                  3.173733                         -1.047087
# 978                 -0.760401                          0.385249
# 97                   1.904990                         -0.330919
# 994                 -0.995626                         -0.330919
#
#       Left Accumbens Area Volume  Left Amygdala Volume  Left Caudate Volume  \
# 1002                    0.149538             -0.149480            -0.231100
# 1009                   -0.011621              0.959332             1.328122
# 1010                   -0.559559             -1.420557            -0.449526
# 1013                   -1.644693             -0.559007            -0.876296
# 1016                    1.589220             -0.091528             0.533389
# ...                          ...                   ...                  ...
# 972                     0.847891             -0.879674            -0.073162
# 973                     1.342110              0.294817             2.519382
# 978                     0.418135             -0.195842            -0.197497
# 97                      0.149538             -0.616958             0.778698
# 994                     0.622269             -0.570597            -0.446166
#
#       Left Cerebellum Gray Matter Volume  ...  Race_Asian  Race_Black  \
# 1002                            0.166799  ...           0           0
# 1009                            2.073308  ...           0           0
# 1010                            1.419924  ...           0           0
# 1013                           -0.288973  ...           0           1
# 1016                            1.079920  ...           0           0
# ...                                  ...  ...         ...         ...
# 972                            -0.173797  ...           0           0
# 973                            -0.046197  ...           0           0
# 978                             0.045312  ...           0           0
# 97                              1.414599  ...           0           0
# 994                            -1.166002  ...           0           0
#
#       Race_Latin/Hispanic  Race_Native American  Race_Other  Race_White  \
# 1002                    0                     0           0           1
# 1009                    0                     0           0           1
# 1010                    0                     0           0           1
# 1013                    0                     0           0           0
# 1016                    0                     0           0           1
# ...                   ...                   ...         ...         ...
# 972                     0                     0           0           1
# 973                     0                     0           0           1
# 978                     0                     0           0           1
# 97                      0                     0           0           1
# 994                     0                     0           0           1
#
#       Sex_Female  Sex_Male     ATN  Cohort
# 1002           1         0  A-T-N-    ADNI
# 1009           0         1  A+T-N-    ADNI
# 1010           0         1  A+T-N-    ADNI
# 1013           0         1  A+T-N-    ADNI
# 1016           1         0  A-T-N-    ADNI
# ...          ...       ...     ...     ...
# 972            0         1  A+T+N+    ADNI
# 973            0         1  A-T-N-    ADNI
# 978            0         1  A+T+N+    ADNI
# 97             1         0  A+T-N-    ADNI
# 994            1         0  A+T+N+    ADNI
#
# [870 rows x 71 columns]

# %%
def cohorts_vs_method(cohortsss):
    """
    cohortsss: selected cohorts for UMAP analysis
    call the functions to preprocess the cohorts
    return: a dictionary where the keys are methods for obtaining thresholds and values are df containing the 
    preprocessed datasets (containing the selected features and cohorts)
    """
    
    result_dfs = dict()
    for method in set(cutoffs_.keys()).difference(["cutoffs_cohort_study"]):
        umap_df = umap_atn_participants(cohort_studies, cohortsss, cutoffs_[method], features_all)
        umap_df_concat = pd.concat(norm_df(umap_df, cohortsss), ignore_index=True)
        
        for i, j in zip(cohortsss, list(range(len(cohortsss)))):
            umap_df_concat.replace({i: j}, inplace=True)
        
        atn_parti = Counter(umap_df_concat['ATN'])
        remove_atn = list()

        for i in atn_parti:

            if atn_parti[i] < 25:
                remove_atn.append(i)

        for atn_r in remove_atn:
            umap_df_concat = umap_df_concat.loc[umap_df_concat['ATN']!=atn_r]
        
        result_dfs[method] = umap_df_concat.dropna(axis=1)
        
    return result_dfs

# %%
cohorts_vs_method(['ADNI', 'EPAD'])['gmm_baseline_cutoffs']
# Out:
#            Age  Cerebrospinal Fluid Volume  \
# 0     0.421829                   -0.013856
# 1     0.352433                    0.518354
# 2     0.130364                    0.215812
# 3     0.630019                    0.076686
# 4     0.699416                   -1.575153
# ...        ...                         ...
# 1798  1.008940                   -0.990552
# 1799 -0.206134                   -0.126090
# 1800  0.198891                    0.661530
# 1801 -0.206134                    0.769107
# 1802  1.008940                   -0.039334
#
#       Clinical Dementia Rating Scale Sum of Boxes (CDRSB)  Education  \
# 0                                             -0.939864     0.748942
# 1                                             -0.939864     0.009760
# 2                                             -0.398806     1.488124
# 3                                             -0.939864     1.488124
# 4                                             -0.939864    -1.099014
# ...                                                 ...          ...
# 1798                                           1.533808     0.423631
# 1799                                          -0.460856    -0.630639
# 1800                                          -0.460856     0.687199
# 1801                                          -0.460856     0.950766
# 1802                                           0.868920     2.532172
#
#       Fourth Ventricle Volume  Geriatric Depression Scale (GDS)  \
# 0                   -1.043784                          0.385826
# 1                   -0.423201                         -0.330708
# 2                    0.985609                          1.102361
# 3                    0.301792                          0.385826
# 4                   -1.315840                         -0.330708
# ...                       ...                               ...
# 1798                -0.736104                          0.810058
# 1799                -0.421587                         -1.054587
# 1800                -1.274629                         -1.054587
# 1801                -0.903849                         -0.640222
# 1802                -0.636298                          2.260338
#
#       Left Accumbens Area Volume  Left Amygdala Volume  Left Caudate Volume  \
# 0                       0.150841             -0.150119            -0.231392
# 1                      -0.010285              0.959172             1.328709
# 2                      -0.558115             -1.421744            -0.449940
# 3                      -1.643033             -0.559822            -0.876951
# 4                       1.590237             -0.092142             0.533528
# ...                          ...                   ...                  ...
# 1798                   -0.534912             -1.673084             0.120344
# 1799                   -0.178271              0.525130             0.317509
# 1800                    0.033065             -0.811393            -0.396596
# 1801                   -1.240029             -0.926827             0.345104
# 1802                   -2.421118             -2.043629            -2.065020
#
#       Left Cerebellum Gray Matter Volume  ...  CDR_1  Race_Asian  Race_Black  \
# 0                               0.167422  ...      0           0           0
# 1                               2.074776  ...      0           0           0
# 2                               1.421103  ...      0           0           0
# 3                              -0.288551  ...      0           0           1
# 4                               1.080948  ...      0           0           0
# ...                                  ...  ...    ...         ...         ...
# 1798                            0.212292  ...      0           0           0
# 1799                            0.427183  ...      0           0           0
# 1800                           -1.078034  ...      0           0           0
# 1801                            0.587515  ...      0           0           0
# 1802                           -0.720831  ...      0           0           0
#
#       Race_Latin/Hispanic  Race_Other  Race_White  Sex_Female  Sex_Male  \
# 0                       0           0           1           1         0
# 1                       0           0           1           0         1
# 2                       0           0           1           0         1
# 3                       0           0           0           0         1
# 4                       0           0           1           1         0
# ...                   ...         ...         ...         ...       ...
# 1798                    0           0           1           1         0
# 1799                    0           0           1           0         1
# 1800                    0           0           1           1         0
# 1801                    0           0           1           1         0
# 1802                    0           0           1           0         1
#
#          ATN  Cohort
# 0     A-T-N-       0
# 1     A+T-N-       0
# 2     A+T-N-       0
# 3     A+T-N-       0
# 4     A-T-N-       0
# ...      ...     ...
# 1798  A+T-N-       1
# 1799  A-T-N-       1
# 1800  A-T-N-       1
# 1801  A+T-N-       1
# 1802  A+T+N+       1
#
# [1773 rows x 69 columns]

# %%
adni_epad = cohorts_vs_method(['ADNI', 'EPAD'])

# %%
# cohorts_vs_method(['EPAD', 'DOD-ADNI'])

# %%
# cohorts_vs_method(['AIBL', 'ARWIBO', 'EDSD', 'PREVENT-AD', 'PharmaCog', 'NACC', 'EMIF'])

# %%
# cohorts_vs_method(['DOD-ADNI', 'EPAD'])

# %%
def plot_result(dfs_dict, list_cohort):
    """"""
    if len(list_cohort) < 3:
        title_cohs = ' and '.join([str(item) for item in list_cohort])
            
    else:
        title_cohs = ', '.join([str(item) for item in list_cohort[:-1]]) + ' and ' + list_cohort[-1]
    
    
    for met in dfs_dict:
        df = dfs_dict[met]
        fig, axes = plt.subplots(len(df['ATN'].unique()), figsize=(5, 3 * len(df['ATN'].unique())))
        
        patches = list()
        colors = np.array(['#2596be', '#154c79', '#ff7f0e', '#2ca02c', '#9467bd', '#8c564b', '#ffbb78', '#98df8a', 
                  '#ff9896', '#c49c94', '#c7c7c7'])
        
        for n in list_cohort:
            patches.append(Line2D([0], [0], color='w', marker='o', markerfacecolor=colors[list_cohort.index(n)], label=n))

        for atn_, ind in zip(df['ATN'].unique(), range(len(df['ATN'].unique()))):
            embedding = umap.UMAP(n_neighbors=5).fit_transform(df.loc[df['ATN']==atn_][df.columns.difference(['Cohort', 'ATN'])], 
                    y=df.loc[df['ATN']==atn_]['Cohort'])
            
            plt.legend(handles=patches)

            scatter = axes[ind].scatter(*embedding.T, s=4, c=colors[df.loc[df['ATN']==atn_]['Cohort']], cmap='Spectral', alpha=1.0, label=list_cohort)
            plt.setp(axes[ind], xticks=[], yticks=[])
                     
            axes[ind].set_title(f'Comparison of participants in {atn_} categorie', fontsize=10)
            fig.suptitle(f'ATN based comparision among {title_cohs} cohorts')
            fig.subplots_adjust(top=0.95, wspace=0.5)
            plt.savefig(f"../results/umap/{met}.png", dpi=300, bbox_inches='tight')

# %%
plot_result(adni_epad, ['ADNI', 'EPAD'])
